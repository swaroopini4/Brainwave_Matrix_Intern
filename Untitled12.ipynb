# %%
pip install pandas scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Load both the Fake and True datasets
fake_df = pd.read_csv('Fake.csv')
real_df = pd.read_csv('True.csv')

# Add label columns to the datasets
fake_df["label"] = "FAKE"
real_df["label"] = "REAL"

# Combine both datasets into one
df = pd.concat([fake_df, real_df], axis=0)

# Shuffle the data to mix fake and real news
df = df.sample(frac=1).reset_index(drop=True)

# Check the data
print(df.head())
# Out:
#                                                title  \
# 0   Vehemently Anti-Gay Pastor Arrested On 70 Cou...
# 1  FLORIDA GOVERNOR GOES OFF ON OBAMA: “The Secon...
# 2  Ramadan Abdullah Set Free On Bail After Police...
# 3  With Obamacare vote, House Republicans free to...
# 4  Iowa governor urges caucus-goers to say 'No' t...
#
#                                                 text       subject  \
# 0  On May 9, Pastor David Reynolds, formerly of C...          News
# 1  Florida Governor Rick Scott is not holding any...     left-news
# 2  How is a man with ties to a US based terror or...      politics
# 3  WASHINGTON (Reuters) - The Republican-controll...  politicsNews
# 4  ALTOONA, Iowa (Reuters) - Iowa’s governor said...  politicsNews
#
#                 date label
# 0       May 15, 2016  FAKE
# 1       Jun 17, 2016  FAKE
# 2       Sep 13, 2017  FAKE
# 3       May 5, 2017   REAL
# 4  January 19, 2016   REAL

# %%
X = df['text']  # This is the news content
y = df['label']  # This is the label (either 'FAKE' or 'REAL')

# %%
# Initialize the TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english', max_df=0.7)

# Fit and transform the training data
X_tfidf = tfidf.fit_transform(X)

# Check the shape of the transformed data
print(X_tfidf.shape)
# Out:
# (44898, 121689)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Check the split
print(f"Training data shape: {X_train.shape}")
print(f"Test data shape: {X_test.shape}")
# Out:
# Training data shape: (35918, 121689)
# Test data shape: (8980, 121689)

# %%
# Initialize and train the model
model = PassiveAggressiveClassifier(max_iter=50)
model.fit(X_train, y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=50)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Print confusion matrix
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9942093541202672
# Confusion Matrix:
#  [[4684   27]
#  [  25 4244]]

# %%
# New test samples
test_samples = [
    "Breaking: Scientists discover water on Mars again!",
    "India's GDP grows 6.5% in the first quarter of 2025.",
    "Aliens found watching IPL final from moon base!",
    "The Finance Minister announces new tax reforms today."
]

# Predict using the trained model
for text in test_samples:
    transformed = tfidf.transform([text])  # Transform the input text to match the TF-IDF format
    result = model.predict(transformed)[0]  # Predict the label
    print(f"Text: {text}\n ➤ Prediction: {result}\n")
# Out:
# Text: Breaking: Scientists discover water on Mars again!
#  ➤ Prediction: FAKE
#
# Text: India's GDP grows 6.5% in the first quarter of 2025.
#  ➤ Prediction: FAKE
#
# Text: Aliens found watching IPL final from moon base!
#  ➤ Prediction: FAKE
#
# Text: The Finance Minister announces new tax reforms today.
#  ➤ Prediction: FAKE

# %%
pip install --upgrade pip
pip install streamlit --no-cache-dir
# Out:
#   Cell In[10], line 1
#     pip install --upgrade pip
#         ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (25.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit --no-cache-dir
# Out:
# Requirement already satisfied: streamlit in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (1.44.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.2.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (19.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (1.35.0)
# Requirement already satisfied: colorama in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: six>=1.5 in c:\users\anuna\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.model_selection import train_test_split

# Load datasets
fake_df = pd.read_csv('Fake.csv')
real_df = pd.read_csv('True.csv')

# Add labels
fake_df['label'] = 'FAKE'
real_df['label'] = 'REAL'

# Combine and shuffle
df = pd.concat([fake_df, real_df])
df = df.sample(frac=1).reset_index(drop=True)

# Prepare data
X = df['text']
y = df['label']

# TF-IDF
tfidf = TfidfVectorizer(stop_words='english', max_df=0.7)
X_tfidf = tfidf.fit_transform(X)

# Split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Train model
model = PassiveAggressiveClassifier(max_iter=50)
model.fit(X_train, y_train)

# Streamlit UI
st.title("📰 Fake News Detection App")
user_input = st.text_area("Enter a news article or headline:")

if st.button("Predict"):
    input_tfidf = tfidf.transform([user_input])
    prediction = model.predict(input_tfidf)[0]
    st.success(f"🧐 The news is predicted to be: **{prediction}**")
# Out:
# 2025-04-16 21:43:44.125 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.151
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\anuna\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-16 21:43:46.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.168 Session state does not function when running a script without `streamlit run`
# 2025-04-16 21:43:46.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:43:46.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.model_selection import train_test_split

# Load datasets
fake_df = pd.read_csv('Fake.csv')
real_df = pd.read_csv('True.csv')

# Add labels
fake_df['label'] = 'FAKE'
real_df['label'] = 'REAL'

# Combine and shuffle
df = pd.concat([fake_df, real_df])
df = df.sample(frac=1).reset_index(drop=True)

# Prepare data
X = df['text']
y = df['label']

# TF-IDF
tfidf = TfidfVectorizer(stop_words='english', max_df=0.7)
X_tfidf = tfidf.fit_transform(X)

# Split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# Train model
model = PassiveAggressiveClassifier(max_iter=50)
model.fit(X_train, y_train)

# Streamlit UI
st.title("📰 Fake News Detection App")
user_input = st.text_area("Enter a news article or headline:")

if st.button("Predict"):
    input_tfidf = tfidf.transform([user_input])
    prediction = model.predict(input_tfidf)[0]
    st.success(f"🧐 The news is predicted to be: **{prediction}**")
# Out:
# 2025-04-16 21:46:46.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-16 21:46:46.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
